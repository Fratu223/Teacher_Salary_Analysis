# %%
# Importing the needed packages

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Plotting the 50 states + District of Columbias' average teacher pay on a column bar chart

df_teacher_pay = pd.read_csv('../Data/teacher-pay-by-state-2024.csv')

plt.figure(figsize=(10, 6))
plt.bar(df_teacher_pay['state'], df_teacher_pay['TeacherPay_AnnualMeanSalary_USD_2024'], color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Annual Mean Salary (USD)')
plt.title('Teacher Pay - Annual Mean Salary (2024)')
plt.tight_layout()
plt.show()

# %%
# Plotting the 50 states + District of Columbias' cost of living index on a column bar chart

df_cost_of_living = pd.read_csv('../Data/cost-of-living-index-by-state-2024.csv')

plt.figure(figsize=(10, 6))
plt.bar(df_cost_of_living['state'], df_cost_of_living['CostOfLivingIndex2023'], color='skyblue')
plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Cost of Living Index')
plt.title('Cost of Living Index (2023)')
plt.tight_layout()
plt.show()

# %%
# Plotting the normalized teacher annual mean salary in USD vs the cost of living index by state for each every state + District of Columbia

df_combined = pd.merge(df_teacher_pay, df_cost_of_living, on='state')

df_combined['NormalizedTeacherPay'] = (df_combined['TeacherPay_AnnualMeanSalary_USD_2024'] - df_combined['TeacherPay_AnnualMeanSalary_USD_2024'].min()) / (df_combined['TeacherPay_AnnualMeanSalary_USD_2024'].max() - df_combined['TeacherPay_AnnualMeanSalary_USD_2024'].min())
df_combined['NormalizedCostOfLiving'] = (df_combined['CostOfLivingIndex2023'] - df_combined['CostOfLivingIndex2023'].min()) / (df_combined['CostOfLivingIndex2023'].max() - df_combined['CostOfLivingIndex2023'].min())

plt.figure(figsize=(14, 8))
plt.bar(df_combined['state'], df_combined['NormalizedTeacherPay'], color='blue', alpha=0.7, label='Normalized Annual Mean Salary (USD)')
plt.plot(df_combined['state'], df_combined['NormalizedCostOfLiving'], color='red', marker='o', label='Normalized Cost of Living')

plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Normalized Values (0 - 1)')
plt.title('Normalized Annual Mean Salary (USD) vs Cost of Living Index by State')

plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plotting the normalized teacher annual mean salary in USD vs the cost of grocery index by state for each every state + District of Columbia

df_combined['NormalizedCostOfLivingGrocery'] = (df_combined['CostOfLivingIndexGroceryCostsIndex'] - df_combined['CostOfLivingIndexGroceryCostsIndex'].min()) / (df_combined['CostOfLivingIndexGroceryCostsIndex'].max() - df_combined['CostOfLivingIndexGroceryCostsIndex'].min())

plt.figure(figsize=(14, 8))
plt.bar(df_combined['state'], df_combined['NormalizedTeacherPay'], color='blue', alpha=0.7, label='Normalized Annual Mean Salary (USD)')
plt.plot(df_combined['state'], df_combined['NormalizedCostOfLivingGrocery'], color='green', marker='o', label='Normalized Cost of Grocery')

plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Normalized Values (0 - 1)')
plt.title('Normalized Annual Mean Salary (USD) vs Cost of Grocery Index by State')

plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plotting the normalized teacher annual mean salary in USD vs the cost of health index by state for each every state + District of Columbia

df_combined['NormalizedCostOfLivingHealth'] = (df_combined['CostOfLivingIndexHealthCostsIndex'] - df_combined['CostOfLivingIndexHealthCostsIndex'].min()) / (df_combined['CostOfLivingIndexHealthCostsIndex'].max() - df_combined['CostOfLivingIndexHealthCostsIndex'].min())

plt.figure(figsize=(14, 8))
plt.bar(df_combined['state'], df_combined['NormalizedTeacherPay'], color='blue', alpha=0.7, label='Normalized Annual Mean Salary (USD)')
plt.plot(df_combined['state'], df_combined['NormalizedCostOfLivingHealth'], color='yellow', marker='o', label='Normalized Cost of Health')

plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Normalized Values (0 - 1)')
plt.title('Normalized Annual Mean Salary vs Cost of Health Index by State')

plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plotting the normalized teacher annual mean salary in USD vs the cost of housing index by state for each every state + District of Columbia

df_combined['NormalizedCostOfLivingHousing'] = (df_combined['CostOfLivingIndexHousingCostsIndex'] - df_combined['CostOfLivingIndexHousingCostsIndex'].min()) / (df_combined['CostOfLivingIndexHousingCostsIndex'].max() - df_combined['CostOfLivingIndexHousingCostsIndex'].min())

plt.figure(figsize=(14, 8))
plt.bar(df_combined['state'], df_combined['NormalizedTeacherPay'], color='blue', alpha=0.7, label='Normalized Annual Mean Salary (USD)')
plt.plot(df_combined['state'], df_combined['NormalizedCostOfLivingHousing'], color='black', marker='o', label='Normalized Cost of Housing')

plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Normalized Values (0 - 1)')
plt.title('Normalized Annual Mean Salary vs Cost of Housing Index by State')

plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plotting the normalized teacher annual mean salary in USD vs the cost of miscellaneous index by state for each every state + District of Columbia

df_combined['NormalizedCostOfLivingMisc'] = (df_combined['CostOfLivingIndexMiscCostsIndex'] - df_combined['CostOfLivingIndexMiscCostsIndex'].min()) / (df_combined['CostOfLivingIndexMiscCostsIndex'].max() - df_combined['CostOfLivingIndexMiscCostsIndex'].min())

plt.figure(figsize=(14, 8))
plt.bar(df_combined['state'], df_combined['NormalizedTeacherPay'], color='blue', alpha=0.7, label='Normalized Annual Mean Salary (USD)')
plt.plot(df_combined['state'], df_combined['NormalizedCostOfLivingMisc'], color='pink', marker='o', label='Normalized Cost of Miscellaneous')

plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Normalized Values (0 - 1)')
plt.title('Normalized Annual Mean Salary vs Cost of Miscellaneous Index by State')

plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plotting the normalized teacher annual mean salary in USD vs the cost of transportation index by state for each every state + District of Columbia

df_combined['NormalizedCostOfLivingTransportation'] = (df_combined['CostOfLivingIndexTransportationCostsIndex'] - df_combined['CostOfLivingIndexTransportationCostsIndex'].min()) / (df_combined['CostOfLivingIndexTransportationCostsIndex'].max() - df_combined['CostOfLivingIndexTransportationCostsIndex'].min())

plt.figure(figsize=(14, 8))
plt.bar(df_combined['state'], df_combined['NormalizedTeacherPay'], color='blue', alpha=0.7, label='Normalized Annual Mean Salary (USD)')
plt.plot(df_combined['state'], df_combined['NormalizedCostOfLivingTransportation'], color='silver', marker='o', label='Normalized Cost of Transportation')

plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Normalized Values (0 - 1)')
plt.title('Normalized Annual Mean Salary vs Cost of Transportation Index by State')

plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plotting the normalized teacher annual mean salary in USD vs the cost of utilities index by state for each every state + District of Columbia

df_combined['NormalizedCostOfLivingUtility'] = (df_combined['CostOfLivingIndexUtilityCostsIndex'] - df_combined['CostOfLivingIndexUtilityCostsIndex'].min()) / (df_combined['CostOfLivingIndexUtilityCostsIndex'].max() - df_combined['CostOfLivingIndexUtilityCostsIndex'].min())

plt.figure(figsize=(14, 8))
plt.bar(df_combined['state'], df_combined['NormalizedTeacherPay'], color='blue', alpha=0.7, label='Normalized Annual Mean Salary (USD)')
plt.plot(df_combined['state'], df_combined['NormalizedCostOfLivingUtility'], color='orange', marker='o', label='Normalized Cost of Utilities')

plt.xticks(rotation=90)
plt.xlabel('State')
plt.ylabel('Normalized Values (0 - 1)')
plt.title('Normalized Annual Mean Salary vs Cost of Utilities Index by State')

plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
